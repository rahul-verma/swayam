# %%
from env import *
from swayam import *

# %%
narrator = Swayam.narrator.expression(narration="test")
narrator.reset()

# %%
narrator.narrate(Expression.drafter_feeder)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# File ~/Documents/GitHub/swayam/swayam/inject/template/template.py:127, in DataTemplate.__call__(self, **fields)
#     126 try:
# --> 127     data_object = self.__model(**fields)
#     128     return Data(self, data_object)
#
# File ~/Documents/lab/pyvenv/py3108/lib/python3.10/site-packages/pydantic/main.py:193, in BaseModel.__init__(self, **data)
#     192 __tracebackhide__ = True
# --> 193 self.__pydantic_validator__.validate_python(data, self_instance=self)
#
# ValidationError: 3 validation errors for ExpressionModel
# prompts.0.str
#   Input should be a valid string [type=string_type, input_value={'draft': {'definitions':...ity': 'depends_feeder'}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# prompts.0.PromptRepeaterModel.repeat
# ...
